# %% [markdown]
# ### Exercise 1: Grade Calculator
#
# Write a program that calculates final grades.

# %%
# Exercise 1: Your code here
# Given a list of student marks:
marks_list = [45, 67, 89, 92, 55, 78, 88, 34, 76, 81]

# Tasks:
# 1. Use a for loop to print each mark with its status (Pass/Fail, passing >= 50)
# 2. Count how many students passed and failed
# 3. Calculate the average mark
# 4. Find the highest and lowest marks
for each_std_mark in marks_list:
    if each_std_mark>=50:
        
        print(f"Pass,mark ={each_std_mark}")
    else:
        print(f"Failed! mark ={each_std_mark}")
for i in marks_list:
    if i >=50:
        pas_std=i
        print(pas_std)
# Out:
# Failed! mark =45
# Pass,mark =67
# Pass,mark =89
# Pass,mark =92
# Pass,mark =55
# Pass,mark =78
# Pass,mark =88
# Failed! mark =34
# Pass,mark =76
# Pass,mark =81
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 15
#      11     if each_std_mark>=50:
#      12         print(f"Pass,mark ={each_std_mark}")
#      13     else:
#      14         print(f"Failed! mark ={each_std_mark}")
# ---> 15 print(marks_list.count())
#      16 for i in marks_list:
#      17     if i >=50:
#      18         pas_std=i
#
# TypeError: list.count() takes exactly one argument (0 given)

# %% [markdown]
# ### Exercise 2: FizzBuzz Challenge

# %%
# Exercise 2: Your code here
# Print numbers from 1 to 30, but:
# - Print "Fizz" for multiples of 3
# - Print "Buzz" for multiples of 5
# - Print "FizzBuzz" for multiples of both 3 and 5
# - Otherwise print the number

# %% [markdown]
# ### Exercise 3: Prime Number Finder

# %%
# Exercise 3: Your code here
# Find all prime numbers between 1 and 50
# A prime number is only divisible by 1 and itself
# Store results in a list

# %% [markdown]
# ### Exercise 4: Password Generator

# %%
# Exercise 4: Your code here
# Create a password validator that checks:
# 1. Length >= 8
# 2. Has at least one uppercase letter
# 3. Has at least one lowercase letter
# 4. Has at least one digit
#
# Test with these passwords:
passwords = ["Pass123", "password", "PASSWORD123", "SecurePass1", "weak"]
#
# For each password, print if it's valid or what requirements it fails

# %% [markdown]
# ### Exercise 5: Shopping Cart Calculator

# %%
# Exercise 5: Your code here
# Given:
cart = [
    {"item": "Laptop", "price": 75000, "quantity": 1},
    {"item": "Mouse", "price": 1500, "quantity": 2},
    {"item": "Keyboard", "price": 3500, "quantity": 1},
    {"item": "Monitor", "price": 25000, "quantity": 1}
]

# Calculate:
# 1. Subtotal for each item (price × quantity)
# 2. Total cart value
# 3. Apply 10% discount if total > 50000
# 4. Add 17% GST
# 5. Display itemized receipt

# %% [markdown]
# ### Exercise 6: Number Guessing Game

# %%
# Exercise 6: Your code here
# Create a number guessing game:
# 1. Generate a random number between 1 and 100
# 2. Give user 7 attempts to guess
# 3. After each guess, tell if the number is higher or lower
# 4. If guessed correctly, congratulate and show attempts used
# 5. If all attempts used, reveal the number
#
# Simulate with a list of guesses (for testing)

import random

# %% [markdown]
# ### Exercise 7: Data Analysis

# %%
# Exercise 7: Your code here
# Analyze temperature data
temperatures = [32, 35, 28, 40, 38, 33, 29, 36, 41, 37, 31, 34, 39, 42]

# Calculate:
# 1. Average temperature
# 2. Maximum and minimum temperatures
# 3. How many days were above average
# 4. How many days were extremely hot (> 38°C)
# 5. Create a list of "Hot" or "Normal" for each day (>35 = Hot)
# Use list comprehension for task 5
