# %% [markdown]
# # Operators and Expressions
#
# ## Introduction
#
# - Operators are special symbols in Python that perform operations on variables and values.
# - An expression is a combination of operators and operands (values or variables) that Python evaluates to produce a result.
# - Understanding operators is crucial for writing effective Python code, as they allow you to perform calculations, make comparisons, combine conditions, and manipulate data.
#
# Think of operators as the verbs of programming - they describe actions to be performed on your data!
#
# **What you'll learn:**
# 1. **Arithmetic Operators** - Mathematical operations (+, -, *, /, //, %, **)
# 2. **Relational (Comparison) Operators** - Comparing values (==, !=, >, <, >=, <=)
# 3. **Logical (Boolean) Operators** - Combining conditions (and, or, not)
# 4. **Membership Operators** - Testing membership (in, not in)
# 5. **Identity Operators** - Comparing object identity (is, is not)
# 6. **Bitwise Operators** - Binary operations (&, |, ^, ~, <<, >>)
# 7. **Assignment Operators** - Assigning values (=, +=, -=, *=, etc.)
#
# Let's explore each type in detail!

# %% [markdown]
# ---
# ## Part 1: Comprehensive Practice

# %% [markdown]
# ## 1. Arithmetic Operators
#
# Arithmetic operators are used to perform mathematical operations.

# %% [markdown]
# ### 1.1 Basic Arithmetic Operators

# %%
# Addition (+)
a = 10
b = 3
result = a + b
print(f"{a} + {b} = {result}")

# Subtraction (-)
result = a - b
print(f"{a} - {b} = {result}")

# Multiplication (*)
result = a * b
print(f"{a} * {b} = {result}")

# Division (/) - always returns float
result = a / b
print(f"{a} / {b} = {result}")
print(f"Type: {type(result)}")

# Even if numbers divide evenly
result = 10 / 2
print(f"10 / 2 = {result} (type: {type(result)})")
# Out:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.3333333333333335
# Type: <class 'float'>
# 10 / 2 = 5.0 (type: <class 'float'>)

# %% [markdown]
# ### 1.2 Floor Division and Modulus

# %%
# Floor Division (//) - returns integer (quotient without remainder)
a = 10
b = 3
result = a // b
print(f"{a} // {b} = {result}")
print("asli division",a/b)
# More examples
print(f"17 // 5 = {17 // 5}")   # 3
print(f"20 // 4 = {20 // 4}")   # 5
print(f"-10 // 3 = {-10 // 3}") # -4 (rounds down)

print()

# Modulus (%) - returns remainder
result = a % b
print(f"{a} % {b} = {result}")


# More examples
print(f"17 % 5 = {17 % 5}")   # 2
print(f"20 % 4 = {20 % 4}")   # 0
print(f"100 % 7 = {100 % 7}") # 2
# Out:
# 10 // 3 = 3
# asli division 3.3333333333333335
# 17 // 5 = 3
# 20 // 4 = 5
# -10 // 3 = -4
#
# 10 % 3 = 1
# 17 % 5 = 2
# 20 % 4 = 0
# 100 % 7 = 2

# %% [markdown]
# ### 1.3 Exponentiation

# %%
# Exponentiation (**) - power operation
base = 2
exponent = 3
result = base ** exponent
print(f"{base} ** {exponent} = {result}")

# More examples
print(f"5 ** 2 = {5 ** 2}")     # 25
print(f"10 ** 3 = {10 ** 3}")   # 1000
print(f"2 ** 8 = {2 ** 8}")     # 256

# Square root using exponent
number = 16
square_root = number ** 0.5
print(f"Square root of {number} = {square_root}")

# Cube root
number = 27
cube_root = number ** (1/3)
print(f"Cube root of {number} = {cube_root:.2f}")
# Out:
# 2 ** 3 = 8
# 5 ** 2 = 25
# 10 ** 3 = 1000
# 2 ** 8 = 256
# Square root of 16 = 4.0
# Cube root of 27 = 3.00

# %% [markdown]
# ### 1.4 Operator Precedence

# %%
# Order of operations: PEMDAS
# Parentheses, Exponents, Multiplication/Division, Addition/Subtraction

# Without parentheses
result = 2 + 3 * 4
print(f"2 + 3 * 4 = {result}")  # 14 (multiplication first)

# With parentheses
result = (2 + 3) * 4
print(f"(2 + 3) * 4 = {result}")  # 20 (addition first)

# Complex expression
result = 2 ** 3 + 4 * 5 - 6 / 2
print(f"2 ** 3 + 4 * 5 - 6 / 2 = {result}")  # 25.0

# Breaking it down:
print("\nStep by step:")
print(f"1. 2 ** 3 = {2 ** 3}")           # 8
print(f"2. 4 * 5 = {4 * 5}")             # 20
print(f"3. 6 / 2 = {6 / 2}")             # 3.0
print(f"4. 8 + 20 - 3.0 = {8 + 20 - 3.0}")  # 25.0
# Out:
# 2 + 3 * 4 = 14
# (2 + 3) * 4 = 20
# 2 ** 3 + 4 * 5 - 6 / 2 = 25.0
#
# Step by step:
# 1. 2 ** 3 = 8
# 2. 4 * 5 = 20
# 3. 6 / 2 = 3.0
# 4. 8 + 20 - 3.0 = 25.0

# %% [markdown]
# ### 1.5 Unary Operators

# %%
# Unary plus (+) - doesn't change the value
x = 5
result = +x
print(f"+{x} = {result}")

# Unary minus (-) - negates the value
x = 5
result = -x
print(f"-{x} = {result}")

# Double negative
x = -5
result = -x
print(f"-({x}) = {result}")
# Out:
# +5 = 5
# -5 = -5
# -(-5) = 5

# %% [markdown]
# ## 2. Relational (Comparison) Operators
#
# Relational operators compare two values and return a boolean (True or False).

# %% [markdown]
# ### 2.1 Basic Comparison Operators

# %%
a = 10
b = 5

# Equal to (==)
print(f"{a} == {b}: {a == b}")  # False
print(f"{a} == 10: {a == 10}")  # True

# Not equal to (!=)
print(f"{a} != {b}: {a != b}")  # True
print(f"{a} != 10: {a != 10}")  # False

# Greater than (>)
print(f"{a} > {b}: {a > b}")    # True
print(f"{b} > {a}: {b > a}")    # False

# Less than (<)
print(f"{a} < {b}: {a < b}")    # False
print(f"{b} < {a}: {b < a}")    # True

# Greater than or equal to (>=)
print(f"{a} >= {b}: {a >= b}")  # True
print(f"{a} >= 10: {a >= 10}")  # True
print(f"{a} >= 15: {a >= 15}")  # False

# Less than or equal to (<=)
print(f"{b} <= {a}: {b <= a}")  # True
print(f"{a} <= 10: {a <= 10}")  # True
print(f"{a} <= 5: {a <= 5}")    # False
# Out:
# 10 == 5: False
# 10 == 10: True
# 10 != 5: True
# 10 != 10: False
# 10 > 5: True
# 5 > 10: False
# 10 < 5: False
# 5 < 10: True
# 10 >= 5: True
# 10 >= 10: True
# 10 >= 15: False
# 5 <= 10: True
# 10 <= 10: True
# 10 <= 5: False

# %% [markdown]
# ### 2.2 Comparing Different Data Types

# %%
# Comparing integers and floats
print(f"10 == 10.0: {10 == 10.0}")  # True (values are equal)
print(f"5 < 5.5: {5 < 5.5}")        # True

# Comparing strings
name1 = "Alice"
name2 = "Bob"
print(f"'{name1}' == '{name2}': {name1 == name2}")  # False
print(f"'{name1}' < '{name2}': {name1 < name2}")    # True (alphabetical)

# Case sensitivity
print(f"'Alice' == 'alice': {'Alice' == 'alice'}")  # False
print(f"'Alice'.lower() == 'alice': {'Alice'.lower() == 'alice'}")  # True

# Comparing booleans
print(f"True == 1: {True == 1}")    # True
print(f"False == 0: {False == 0}")  # True
print(f"True > False: {True > False}")  # True
# Out:
# 10 == 10.0: True
# 5 < 5.5: True
# 'Alice' == 'Bob': False
# 'Alice' < 'Bob': True
# 'Alice' == 'alice': False
# 'Alice'.lower() == 'alice': True
# True == 1: True
# False == 0: True
# True > False: True

# %% [markdown]
# ### 2.3 Chaining Comparisons

# %%
# Python allows chaining comparisons
x = 5

# Check if x is between 1 and 10
result = 1 < x < 10
print(f"1 < {x} < 10: {result}")  # True

# Equivalent to:
result = (1 < x) and (x < 10)
print(f"(1 < {x}) and ({x} < 10): {result}")  # True

# More examples
age = 25
print(f"18 <= {age} <= 65: {18 <= age <= 65}")  # True

score = 85
print(f"60 <= {score} < 70: {60 <= score < 70}")  # False
print(f"80 <= {score} < 90: {80 <= score < 90}")  # True
# Out:
# 1 < 5 < 10: True
# (1 < 5) and (5 < 10): True
# 18 <= 25 <= 65: True
# 60 <= 85 < 70: False
# 80 <= 85 < 90: True

# %% [markdown]
# ## 3. Logical (Boolean) Operators
#
# Logical operators are used to combine conditional statements.

# %% [markdown]
# ### 3.1 AND Operator

# %%
# AND operator - both conditions must be True
print("=== AND Operator ===")
print(f"True and True: {True and True}")      # True
print(f"True and False: {True and False}")    # False
print(f"False and True: {False and True}")    # False
print(f"False and False: {False and False}")  # False

print()

# Practical example
age = 25
has_license = True

can_drive = (age >= 18) and has_license
print(f"Can drive? {can_drive}")  # True

# Another example
temperature = 75
is_sunny = True

good_weather = (temperature > 70) and is_sunny
print(f"Good weather? {good_weather}")  # True
# Out:
# === AND Operator ===
# True and True: True
# True and False: False
# False and True: False
# False and False: False
#
# Can drive? True
# Good weather? True

# %% [markdown]
# ### 3.2 OR Operator

# %%
# OR operator - at least one condition must be True
print("=== OR Operator ===")
print(f"True or True: {True or True}")      # True
print(f"True or False: {True or False}")    # True
print(f"False or True: {False or True}")    # True
print(f"False or False: {False or False}")  # False

print()

# Practical example
is_weekend = True
is_holiday = False

can_relax = is_weekend or is_holiday
print(f"Can relax? {can_relax}")  # True

# Another example
has_coupon = False
is_member = True

gets_discount = has_coupon or is_member
print(f"Gets discount? {gets_discount}")  # True
# Out:
# === OR Operator ===
# True or True: True
# True or False: True
# False or True: True
# False or False: False
#
# Can relax? True
# Gets discount? True

# %% [markdown]
# ### 3.3 NOT Operator

# %%
# NOT operator - inverts the boolean value
print("=== NOT Operator ===")
print(f"not True: {not True}")    # False
print(f"not False: {not False}")  # True

print()

# Practical example
is_raining = False
is_sunny = not is_raining
print(f"Is sunny? {is_sunny}")  # True

# With comparisons
x = 5
print(f"not (x > 10): {not (x > 10)}")  # True
print(f"not (x == 5): {not (x == 5)}")  # False

# Double negative
value = True
print(f"not not {value}: {not not value}")  # True
# Out:
# === NOT Operator ===
# not True: False
# not False: True
#
# Is sunny? True
# not (x > 10): True
# not (x == 5): False
# not not True: True

# %% [markdown]
# ### 3.4 Combining Logical Operators

# %%
# Complex conditions
age = 25
has_license = True
has_car = False

# AND with OR
result = (age >= 18 and has_license) or has_car
print(f"Result 1: {result}")  # True

# Using parentheses for clarity
score = 85
attendance = 90

passes = (score >= 60) and (attendance >= 75)
print(f"Student passes? {passes}")  # True

# More complex example
temperature = 75
is_weekend = True
has_plans = False

go_outside = (temperature > 70 and is_weekend) and not has_plans
print(f"Go outside? {go_outside}")  # True
# Out:
# Result 1: True
# Student passes? True
# Go outside? True

# %% [markdown]
# ### 3.5 Short-Circuit Evaluation

# %%
# Python uses short-circuit evaluation
# For AND: if first is False, doesn't evaluate second
# For OR: if first is True, doesn't evaluate second

# AND short-circuit
x = 0
result = (x != 0) and (10 / x > 5)  # Doesn't cause error
print(f"AND short-circuit: {result}")  # False

# If we didn't have short-circuit, this would cause division by zero error
# Uncomment to see error:
# result = (10 / x > 5) and (x != 0)  # Error!

# OR short-circuit
has_permission = True
# result = has_permission or (1/0 > 0)  # Would not evaluate second part
print(f"OR short-circuit example: {has_permission or False}")  # True
# Out:
# AND short-circuit: False
# OR short-circuit example: True

# %% [markdown]
# ## 4. Membership Operators
#
# Membership operators test whether a value is found in a sequence (string, list, tuple, etc.).

# %% [markdown]
# ### 4.1 The 'in' Operator

# %%
# Check if value is in a string
text = "Python Programming"
print(f"'Python' in '{text}': {'Python' in text}")  # True
print(f"'Java' in '{text}': {'Java' in text}")      # False
print(f"'python' in '{text}': {'python' in text}")  # False (case-sensitive)

print()

# Check if value is in a list
fruits = ["apple", "banana", "cherry"]
print(f"'apple' in {fruits}: {'apple' in fruits}")    # True
print(f"'orange' in {fruits}: {'orange' in fruits}")  # False

print()

# Check if value is in a tuple
numbers = (1, 2, 3, 4, 5)
print(f"3 in {numbers}: {3 in numbers}")  # True
print(f"6 in {numbers}: {6 in numbers}")  # False

print()

# Check if key is in a dictionary
person = {"name": "Alice", "age": 25}
print(f"'name' in {person}: {'name' in person}")      # True
print(f"'address' in {person}: {'address' in person}")  # False
# Out:
# 'Python' in 'Python Programming': True
# 'Java' in 'Python Programming': False
# 'python' in 'Python Programming': False
#
# 'apple' in ['apple', 'banana', 'cherry']: True
# 'orange' in ['apple', 'banana', 'cherry']: False
#
# 3 in (1, 2, 3, 4, 5): True
# 6 in (1, 2, 3, 4, 5): False
#
# 'name' in {'name': 'Alice', 'age': 25}: True
# 'address' in {'name': 'Alice', 'age': 25}: False

# %% [markdown]
# ### 4.2 The 'not in' Operator

# %%
# Check if value is NOT in a sequence
text = "Python Programming"
print(f"'Java' not in '{text}': {'Java' not in text}")  # True
print(f"'Python' not in '{text}': {'Python' not in text}")  # False

print()

# With lists
colors = ["red", "blue", "green"]
print(f"'yellow' not in {colors}: {'yellow' not in colors}")  # True
print(f"'red' not in {colors}: {'red' not in colors}")        # False

print()

# Practical example
allowed_users = ["alice", "bob", "charlie"]
username = "dave"

if username not in allowed_users:
    print(f"{username} is not an allowed user")
else:
    print(f"{username} is an allowed user")
# Out:
# 'Java' not in 'Python Programming': True
# 'Python' not in 'Python Programming': False
#
# 'yellow' not in ['red', 'blue', 'green']: True
# 'red' not in ['red', 'blue', 'green']: False
#
# dave is not an allowed user

# %% [markdown]
# ## 5. Identity Operators
#
# Identity operators compare the memory locations of two objects (not their values).

# %% [markdown]
# ### 5.1 The 'is' Operator

# %%
# 'is' checks if two variables point to the same object in memory
a = [1, 2, 3]
b = a  # b points to the same list as a
c = [1, 2, 3]  # c is a new list with same values

print(f"a is b: {a is b}")  # True (same object)
print(f"a is c: {a is c}")  # False (different objects)
print(f"a == c: {a == c}")  # True (same values)

print()

# With None
x = None
y = None
print(f"x is None: {x is None}")  # True
print(f"y is None: {y is None}")  # True
print(f"x is y: {x is y}")        # True (None is a singleton)

print()

# With small integers (Python caches small integers)
x = 5
y = 5
print(f"x is y: {x is y}")  # True (cached)

# With large integers
x = 1000
y = 1000
print(f"x is y (large numbers): {x is y}")  # May be False (not cached)
# Out:
# a is b: True
# a is c: False
# a == c: True
#
# x is None: True
# y is None: True
# x is y: True
#
# x is y: True
# x is y (large numbers): False

# %% [markdown]
# ### 5.2 The 'is not' Operator

# %%
# 'is not' checks if two variables point to different objects
a = [1, 2, 3]
b = [1, 2, 3]

print(f"a is not b: {a is not b}")  # True (different objects)

# With None
x = 10
print(f"x is not None: {x is not None}")  # True

# Common use case: checking for None
value = None
if value is None:
    print("Value is None")

value = 42
if value is not None:
    print("Value is not None")
# Out:
# a is not b: True
# x is not None: True
# Value is None
# Value is not None

# %% [markdown]
# ### 5.3 Understanding id() Function

# %%
# id() returns the memory address of an object
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(f"id(a): {id(a)}")
print(f"id(b): {id(b)}")
print(f"id(c): {id(c)}")

print()
print(f"a is b: {a is b}  # Same id? {id(a) == id(b)}")
print(f"a is c: {a is c}  # Same id? {id(a) == id(c)}")
# Out:
# id(a): 2261404009152
# id(b): 2261404009152
# id(c): 2261404520576
#
# a is b: True  # Same id? True
# a is c: False  # Same id? False

# %% [markdown]
# ## 6. Bitwise Operators
#
# Bitwise operators work on binary representations of numbers.

# %% [markdown]
# ### 6.1 Bitwise AND (&)

# %%
# Bitwise AND: 1 if both bits are 1, else 0
a = 12  # Binary: 1100
b = 10  # Binary: 1010
result = a & b  # Binary: 1000 = 8

print(f"{a} & {b} = {result}")
print(f"Binary: {bin(a)} & {bin(b)} = {bin(result)}")

# More examples
print(f"5 & 3 = {5 & 3}")   # 0101 & 0011 = 0001 = 1
print(f"7 & 3 = {7 & 3}")   # 0111 & 0011 = 0011 = 3
# Out:
# 12 & 10 = 8
# Binary: 0b1100 & 0b1010 = 0b1000
# 5 & 3 = 1
# 7 & 3 = 3

# %% [markdown]
# ### 6.2 Bitwise OR (|)

# %%
# Bitwise OR: 1 if at least one bit is 1
a = 12  # Binary: 1100
b = 10  # Binary: 1010
result = a | b  # Binary: 1110 = 14

print(f"{a} | {b} = {result}")
print(f"Binary: {bin(a)} | {bin(b)} = {bin(result)}")

# More examples
print(f"5 | 3 = {5 | 3}")   # 0101 | 0011 = 0111 = 7
print(f"8 | 4 = {8 | 4}")   # 1000 | 0100 = 1100 = 12
# Out:
# 12 | 10 = 14
# Binary: 0b1100 | 0b1010 = 0b1110
# 5 | 3 = 7
# 8 | 4 = 12

# %% [markdown]
# ### 6.3 Bitwise XOR (^)

# %%
# Bitwise XOR: 1 if bits are different
a = 12  # Binary: 1100
b = 10  # Binary: 1010
result = a ^ b  # Binary: 0110 = 6

print(f"{a} ^ {b} = {result}")
print(f"Binary: {bin(a)} ^ {bin(b)} = {bin(result)}")

# More examples
print(f"5 ^ 3 = {5 ^ 3}")   # 0101 ^ 0011 = 0110 = 6
print(f"7 ^ 7 = {7 ^ 7}")   # 0111 ^ 0111 = 0000 = 0

# XOR trick: swapping without temp variable
x = 5
y = 10
print(f"Before swap: x = {x}, y = {y}")
x = x ^ y
y = x ^ y
x = x ^ y
print(f"After swap: x = {x}, y = {y}")
# Out:
# 12 ^ 10 = 6
# Binary: 0b1100 ^ 0b1010 = 0b110
# 5 ^ 3 = 6
# 7 ^ 7 = 0
# Before swap: x = 5, y = 10
# After swap: x = 10, y = 5

# %% [markdown]
# ### 6.4 Bitwise NOT (~)

# %%
# Bitwise NOT: inverts all bits (returns -(n+1))
a = 5   # Binary: 0101
result = ~a  # -6

print(f"~{a} = {result}")

# More examples
print(f"~10 = {~10}")  # -11
print(f"~0 = {~0}")    # -1
print(f"~(-1) = {~(-1)}")  # 0
# Out:
# ~5 = -6
# ~10 = -11
# ~0 = -1
# ~(-1) = 0

# %% [markdown]
# ### 6.5 Left Shift (<<) and Right Shift (>>)

# %%
# Left shift: shifts bits to the left (multiply by 2^n)
a = 5  # Binary: 0101
result = a << 1  # Binary: 1010 = 10
print(f"{a} << 1 = {result}")  # 5 * 2 = 10

result = a << 2  # Binary: 10100 = 20
print(f"{a} << 2 = {result}")  # 5 * 4 = 20

print()

# Right shift: shifts bits to the right (divide by 2^n)
a = 20  # Binary: 10100
result = a >> 1  # Binary: 1010 = 10
print(f"{a} >> 1 = {result}")  # 20 / 2 = 10

result = a >> 2  # Binary: 101 = 5
print(f"{a} >> 2 = {result}")  # 20 / 4 = 5

# Quick multiplication and division by powers of 2
print(f"16 << 2 = {16 << 2}")  # 16 * 4 = 64
print(f"100 >> 3 = {100 >> 3}")  # 100 / 8 = 12
# Out:
# 5 << 1 = 10
# 5 << 2 = 20
#
# 20 >> 1 = 10
# 20 >> 2 = 5
# 16 << 2 = 64
# 100 >> 3 = 12

# %% [markdown]
# ## 7. Assignment Operators
#
# Assignment operators are used to assign values to variables.

# %% [markdown]
# ### 7.1 Basic Assignment (=)

# %%
# Basic assignment
x = 10
print(f"x = {x}")

# Assigning from expression
y = x + 5
print(f"y = {y}")

# Multiple assignment
a = b = c = 0
print(f"a = {a}, b = {b}, c = {c}")
# Out:
# x = 10
# y = 15
# a = 0, b = 0, c = 0

# %% [markdown]
# ### 7.2 Compound Assignment Operators

# %%
# Add and assign (+=)
x = 10
x += 5  # Same as: x = x + 5
print(f"After x += 5: {x}")

# Subtract and assign (-=)
x = 10
x -= 3  # Same as: x = x - 3
print(f"After x -= 3: {x}")

# Multiply and assign (*=)
x = 10
x *= 2  # Same as: x = x * 2
print(f"After x *= 2: {x}")

# Divide and assign (/=)
x = 10
x /= 2  # Same as: x = x / 2
print(f"After x /= 2: {x}")

# Floor divide and assign (//=)
x = 10
x //= 3  # Same as: x = x // 3
print(f"After x //= 3: {x}")

# Modulus and assign (%=)
x = 10
x %= 3  # Same as: x = x % 3
print(f"After x %= 3: {x}")

# Exponent and assign (**=)
x = 2
x **= 3  # Same as: x = x ** 3
print(f"After x **= 3: {x}")
# Out:
# After x += 5: 15
# After x -= 3: 7
# After x *= 2: 20
# After x /= 2: 5.0
# After x //= 3: 3
# After x %= 3: 1
# After x **= 3: 8

# %% [markdown]
# ### 7.3 Bitwise Compound Assignment

# %%
# Bitwise AND and assign (&=)
x = 12  # 1100
x &= 10  # Same as: x = x & 10
print(f"After x &= 10: {x}")

# Bitwise OR and assign (|=)
x = 12  # 1100
x |= 10  # Same as: x = x | 10
print(f"After x |= 10: {x}")

# Bitwise XOR and assign (^=)
x = 12  # 1100
x ^= 10  # Same as: x = x ^ 10
print(f"After x ^= 10: {x}")

# Left shift and assign (<<=)
x = 5
x <<= 2  # Same as: x = x << 2
print(f"After x <<= 2: {x}")

# Right shift and assign (>>=)
x = 20
x >>= 2  # Same as: x = x >> 2
print(f"After x >>= 2: {x}")
# Out:
# After x &= 10: 8
# After x |= 10: 14
# After x ^= 10: 6
# After x <<= 2: 20
# After x >>= 2: 5

# %% [markdown]
# ### 7.4 Practical Examples with Assignment Operators

# %%
# Counter example
count = 0
count += 1  # Increment
count += 1
count += 1
print(f"Count: {count}")

# Score accumulation
total_score = 0
total_score += 50  # Level 1
total_score += 75  # Level 2
total_score += 100  # Level 3
print(f"Total Score: {total_score}")

# String concatenation
message = "Hello"
message += " "
message += "World"
print(f"Message: {message}")

# List extension
numbers = [1, 2, 3]
numbers += [4, 5]
print(f"Numbers: {numbers}")
# Out:
# Count: 3
# Total Score: 225
# Message: Hello World
# Numbers: [1, 2, 3, 4, 5]

# %% [markdown]
# ### 7.5 Walrus Operator (:=) - Python 3.8+

# %%
# Walrus operator: assigns and returns value in same expression

# Without walrus operator
name = "Alice"
if len(name) > 3:
    print(f"{name} has more than 3 characters")

# With walrus operator
if (n := len("Alice")) > 3:
    print(f"Length {n} is more than 3")

# Useful in loops (conceptual example)
data = [1, 2, 3, 4, 5]
if (length := len(data)) > 3:
    print(f"Data has {length} elements")
# Out:
# Alice has more than 3 characters
# Length 5 is more than 3
# Data has 5 elements

# %% [markdown]
# ---
# ## Part 2: In-Class Tasks
#
# Now it's your turn! Complete these tasks during the class session.

# %% [markdown]
# ### Task 1: Arithmetic Operations
# Create two variables `a = 25` and `b = 7`. Calculate and print:
# 1. Sum
# 2. Difference
# 3. Product
# 4. Quotient (float division)
# 5. Floor division result
# 6. Remainder

# %%
# Write your code here

# %% [markdown]
# ### Task 2: Power and Root
# Calculate 2 raised to the power of 10, and find the square root of 144 using the exponentiation operator.

# %%
# Write your code here

# %% [markdown]
# ### Task 3: Comparison Challenge
# Create variables `x = 15` and `y = 20`. Check and print:
# 1. Is x equal to y?
# 2. Is x less than y?
# 3. Is x greater than or equal to 10?
# 4. Is x between 10 and 25? (use chained comparison)

# %%
# Write your code here

# %% [markdown]
# ### Task 4: Logical Operators Practice
# Create variables: `age = 22`, `has_id = True`, `is_citizen = True`.
# Create a boolean variable `can_vote` that is True only if age is 18 or above AND the person has ID AND is a citizen.

# %%
# Write your code here

# %% [markdown]
# ### Task 5: Membership Test
# Create a list of your favorite colors. Check if "blue" and "purple" are in the list. Print appropriate messages.

# %%
# Write your code here

# %% [markdown]
# ### Task 6: Identity Check
# Create two lists with the same values `[1, 2, 3]`. Assign one to another variable. Check:
# 1. Are they equal (==)?
# 2. Do they refer to the same object (is)?

# %%
# Write your code here
list1=[1, 2, 3]
list2=[1, 2, 3]
print(list1==list2)
print(id(list1))
print(id(list2))
list1 is list2
# Out:
# True
# 2261404579392
# 2261404419648
# False

# %% [markdown]
# ### Task 7: Bitwise Operations
# Use bitwise operators on `a = 6` (binary: 0110) and `b = 3` (binary: 0011). Calculate:
# 1. a & b
# 2. a | b
# 3. a ^ b

# %%
# Write your code here
a=6
b=3
print(a & b)
print(a | b)
print(a ^ b)
# Out:
# 2
# 7
# 5

# %% [markdown]
# ### Task 8: Shift Operations
# Create a variable `num = 4`. Use shift operators to:
# 1. Multiply it by 8 (using left shift)
# 2. Divide it by 2 (using right shift)

# %%
# Write your code here
num=4
print(num>>8)
print(num<<2)
# Out:
# 0
# 16

# %% [markdown]
# ### Task 9: Compound Assignment
# Start with `score = 100`. Use compound assignment operators to:
# 1. Add 50
# 2. Subtract 25
# 3. Multiply by 2
# 4. Divide by 5
#
# Print the score after each operation.

# %%
# Write your code here
score=100
print(score+50)
print(score-25)
print(score*2)
print(score/5)
# Out:
# 150
# 75
# 200
# 20.0

# %% [markdown]
# ### Task 10: Complex Expression
# Evaluate the expression: `result = (10 + 5) * 3 - 20 / 4 ** 2`
#
# Print the result and show the step-by-step breakdown following operator precedence.

# %%
# Write your code here
#result = (10 + 5) * 3 - 20 / 4 ** 2
#PEMDAS
parent=(10+5)
mult=parent*3
div=mult/16
sub=mult-20
last_ans=sub
print(parent)
print(mult)
print(div)
print(sub)
print("\n",last_ans)
# Out:
# 15
# 45
# 2.8125
# 25
#
#  25

# %% [markdown]
# ---
# ## Part 3: Homework Tasks
#
# Complete these tasks at home to reinforce your learning.

# %% [markdown]
# ### Homework Task 1: Calculator Program
# Create a simple calculator that performs all arithmetic operations on two numbers. Store the numbers in variables and display:
# ```
# Number 1: 45
# Number 2: 7
# -------------------
# Sum: 52
# Difference: 38
# Product: 315
# Quotient: 6.43
# Floor Division: 6
# Remainder: 3
# Power: 45^7 = ...
# ```

# %%
# Write your code here
number1=45
number2=7
print("------------------")
print("Sum: ",number1+number2)
print("Difference: ",number1-number2)
div=number1/number2
print("Product: ",number1*number2)
print(div)
print(f"Qoutient:{div:.2f}" )
print("Floor Division: ",number1//number2)
print("REmainder: ",number1%number2)
print("Power: ",number1**number2)
# Out:
# ------------------
# Sum:  52
# Difference:  38
# Product:  315
# 6.428571428571429
# Qoutient:6.43
# Floor Division:  6
# REmainder:  3
# Power:  373669453125

# %% [markdown]
# ### Homework Task 2: Even or Odd Checker
# Create a program that checks if multiple numbers are even or odd using the modulus operator. Test with at least 5 different numbers.
#
# Example output:
# ```
# 17 is odd
# 24 is even
# ```

# %%
# Write your code here

num=int(input("Enter the number you wanna check: "))
even=(num%2)==0
odd=(num%2)!=0
print(num)
print("is even: ",even)
print("is odd: ",odd)
# Out:
# 6
# is even:  True
# is odd:  False

# %% [markdown]
# ### Homework Task 3: Grade Eligibility System
# Create variables for a student:
# - `score = 75`
# - `attendance = 85`
# - `submitted_project = True`
#
# A student passes if:
# - Score is 60 or above AND
# - Attendance is 75% or above AND
# - Project is submitted
#
# Also check if the student gets honors (score >= 90 AND attendance >= 90).
#
# Print appropriate messages for both conditions.

# %%
# Write your code here
score=75
attendance=85
submitted_project=True
std_pass=score>=60 and attendance>=75 and submitted_project
honor_std=score>=90 and attendance>=90
print(f"Student condition ,pass =>{std_pass}")
print(f"Student will get honor ? =>{honor_std}")
# Out:
# Student condition ,pass =>True
# Student will get honor ? =>False

# %%
# Write your code here
score=int(input("Enter the score of the student:"))
attendance=float(input("Enter the attendance of the student:"))
submitted_project=bool(input("Are student submitted the project,True and false : "))

std_pass=score>=60 and attendance>=75 and submitted_project

honor_std=score>=90 and attendance>=90
print(f"Student condition ,pass =>{std_pass}")
print(f"Student will get honor ? =>{honor_std}")
# Out:
# Student condition ,pass =>True
# Student will get honor ? =>True

# %% [markdown]
# ### Homework Task 4: String Membership Checker
# Create a program that checks if certain words exist in a sentence.
#
# Example:
# ```python
# sentence = "Python is an amazing programming language"
# ```
#
# Check for: "Python", "Java", "programming", "difficult"
#
# Print whether each word is found or not found.

# %%
# Write your code here
sentence = "Python is an amazing programming language"
check=input("input the word to check :")
print(sentence.find(check))
# Out:
# 0

# %% [markdown]
# ### Homework Task 5: Age Category Classifier
# Create a program that classifies age into categories using chained comparisons:
# - Child: 0-12
# - Teenager: 13-19
# - Adult: 20-64
# - Senior: 65+
#
# Test with ages: 8, 16, 35, 70

# %%
# Write your code here
age=int(input("Enter your age: "))
child=age>=0 and age<=12
teenager=age>12 and age<=19
adult=age>20 and age<=64
senior=(age>=65)
print("age : ",age)
print(f"child : {child}\nTeenager : {teenager}\nAdult : {adult}\nSenior : {senior}")
# Out:
# age :  0
# child : True
# Teenager : False
# Adult : False
# Senior : False

# %% [markdown]
# ### Homework Task 6: List Operations
# Create two lists:
# ```python
# list1 = [1, 2, 3]
# list2 = [1, 2, 3]
# ```
#
# 1. Create `list3` that points to `list1`
# 2. Test equality (==) and identity (is) for all combinations
# 3. Modify `list1` and observe what happens to `list3`
# 4. Print id() for all lists to understand memory references

# %%
# Write your code here
list1=[1.2,]
list2=[1,2,3]
list3=list1
print(id(list1))
print(id(list2))
print(id(list3))
# Out:
# 2863952779200
# 2863952783808
# 2863952779200

# %% [markdown]
# ### Homework Task 7: Binary Number Explorer
# Pick a number (e.g., 45) and show:
# 1. Its binary representation
# 2. Result after left shift by 2
# 3. Result after right shift by 2
# 4. Result of AND, OR, XOR with another number of your choice
#
# Display all results in both decimal and binary format.

# %%
# Write your code here
num=int(input("Enter a number : "))
result=num>>2
print("greater sign",result)
result1=num<<2
print("greater sign",result1)
# Out:
# greater sign 0
# greater sign 4

# %% [markdown]
# ### Homework Task 8: Score Tracking System
# Create a game score tracker using compound assignment operators:
#
# Start with `score = 0`
# 1. Player completes level 1: add 100 points
# 2. Player finds bonus: multiply score by 1.5
# 3. Player loses a life: subtract 25 points
# 4. Player completes level 2: add 150 points
# 5. Apply final multiplier: multiply by 2
#
# Print the score after each step with descriptive messages.

# %%
# Write your code here
score=0
print("Initial score is zero.\nscore = ",score)
level1=score +100
print("Level 1 completed successfuly!\n New score = ",level1)
bonus=score+level1*1.5
print("BONUS added,New score = ",bonus)
loselife=bonus-25
print("Player dismissed!\nNew score = ",loselife)
level2=loselife+150
print("Level 2 completed successfuly!\n New score = ",level2)
finalmultipl=level2*2
print("Final score = ",finalmultipl)
# Out:
# Initial score is zero.
# score =  0
# Level 1 completed successfuly!
#  New score =  100
# BONUS added,New score =  150.0
# Player dismissed!
# New score =  125.0
# Level 2 completed successfuly!
#  New score =  275.0
# Final score =  550.0

# %% [markdown]
# ### Homework Task 9: Weather Decision Maker
# Create a program that decides whether to go outside based on multiple conditions:
#
# Variables:
# ```python
# temperature = 72
# is_raining = False
# is_weekend = True
# has_umbrella = True
# ```
#
# Go outside if:
# - Temperature is between 60 and 85 AND
# - Either it's not raining OR you have an umbrella AND
# - It's the weekend
#
# Test with different combinations of values.

# %%
# Write your code here
temperature=75
is_raining=False
is_weekend=True
has_umbrella=True
cond1=temperature in range(60,85)
print(cond1)
cond2=not is_raining or has_umbrella
print(cond2)
go_outside=is_weekend and cond1 and cond2
print(go_outside)
print(f"Temprature range is : {cond1}\nno rain and if so, has umbrella ? {cond2}\nabove all and does weekend ? {go_outside}")
# Out:
# True
# True
# True
# Temprature range is : True
# no rain and if so, has umbrella ? True
# above all and does weekend ? True

# %% [markdown]
# ### Homework Task 10: Operator Mastery Challenge
# Create a comprehensive program that:
#
# 1. Uses at least one operator from each category
# 2. Solves a real-world problem (your choice)
# 3. Includes clear comments explaining each operator usage
#
# Ideas:
# - Shopping cart with discounts and tax calculation
# - Student grade calculator with multiple criteria
# - Game character stats manager
# - Ticket booking system
#
# Be creative and demonstrate your understanding of all operator types! 🎨

# %%
# Write your code here - Be Creative!

# %% [markdown]
# ---
# ## Summary
#
# Congratulations! You've learned about all types of operators in Python. Here's what we covered:
#
# ### 1. Arithmetic Operators ✅
# - Basic operations: +, -, *, /
# - Floor division: //
# - Modulus: %
# - Exponentiation: **
# - Operator precedence (PEMDAS)
#
# ### 2. Relational (Comparison) Operators ✅
# - Equality: ==, !=
# - Comparison: >, <, >=, <=
# - Chained comparisons
#
# ### 3. Logical (Boolean) Operators ✅
# - AND, OR, NOT
# - Short-circuit evaluation
# - Combining conditions
#
# ### 4. Membership Operators ✅
# - in, not in
# - Testing in strings, lists, tuples, dictionaries
#
# ### 5. Identity Operators ✅
# - is, is not
# - Comparing object identity vs equality
# - Understanding id()
#
# ### 6. Bitwise Operators ✅
# - AND (&), OR (|), XOR (^), NOT (~)
# - Left shift (<<), Right shift (>>)
# - Binary operations
#
# ### 7. Assignment Operators ✅
# - Basic assignment: =
# - Compound assignment: +=, -=, *=, /=, //=, %=, **=
# - Bitwise compound: &=, |=, ^=, <<=, >>=
# - Walrus operator: :=
#
# **Next Topic:** Control Flow Statements (if-elif-else, loops) - where we'll use these operators to make decisions! 🚀
