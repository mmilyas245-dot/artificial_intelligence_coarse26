# %% [markdown]
# # Assignment 1:

# %%
#basic information:
info = "Muhammad Ilyas from Maidan Lower Dir"
print(info)
# Out:
# Muhammad Ilyas from Maidan Lower Dir

# %% [markdown]
# ### 1:upper() funct:

# %% [markdown]
# upper function capitalize the whole character in string data type

# %%
info.upper()
# Out:
# 'MUHAMMAD ILYAS FROM MAIDAN LOWER DIR'

# %% [markdown]
# ### 2:lower() functio:

# %% [markdown]
# lower function is used to convert string into lower case

# %%
info.lower()
# Out:
# 'muhammad ilyas from maidan lower dir'

# %% [markdown]
# ### 3:title() functio:

# %% [markdown]
# title function is applied on string to make it title,it make starting word capital as well as whenspacing occur so the first word after space isalso capitalized

# %%
titl=info.title()
print(titl)
# Out:
# Muhammad Ilyas From Maidan Lower Dir

# %% [markdown]
# ### 4:capitalize() func:

# %% [markdown]
# it only capitalize the first word of the whole string

# %%
info.capitalize()
# Out:
# 'Muhammad ilyas from maidan lower dir province Khyber pakhtunkhwa'

# %%
#checking whether after '.' word capitize
info2='Muhammad ilyas from maidan lower dir.i am studying artificial intelligence'#answer is no
info2.capitalize()
# Out:
# 'Muhammad ilyas from maidan lower dir.i am studying artificial intelligence'

# %% [markdown]
# ### 5:swapcase()

# %% [markdown]
# swapcase function is mukammal opposite of human mind

# %% [markdown]
# if we have made a word lower case so it is converted into upper case and vise versa

# %%
print(f"original: {info}")
info.swapcase()
# Out:
# original:Muhammad Ilyas from Maidan Lower Dir
# 'mUHAMMAD iLYAS FROM mAIDAN lOWER dIR'

# %% [markdown]
# ### 6:strip() fun:

# %% [markdown]
# strip function remove white spaces from the

# %%
#strip function remove extra whitespace from both left and right side
info3='         Muhammad Ilyas from Maidan Lower Dir        '
info3.strip()
# Out:
# 'Muhammad Ilyas from Maidan Lower Dir'

# %%
info4='      Muhammad Ilyas from Maidan Lower Dir    '

# %%
#lstrip function remove white space from left side while rstrip function remove from right sight
print(info4.lstrip())
info4.rstrip()
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# '      Muhammad Ilyas from Maidan Lower Dir'

# %% [markdown]
# ### 7:replace() func:

# %% [markdown]
# replace func replace the word or a single character with another character therefore it take two argument

# %%
print(info)#original
info.replace("a",'b')#replace all occurence of a in the string by b
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# 'Muhbmmbd Ilybs from Mbidbn Lower Dir'

# %%
print(info)#original
info.replace('Muhammad','ahmad')
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# 'ahmad Ilyas from Maidan Lower Dir'

# %% [markdown]
# ### 8 find function:

# %% [markdown]
# find function are used to find the index of any word in the given string

# %%
print(info)
info.find('d')#return the first occurence index and ignore rest
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# 7

# %% [markdown]
# ### 9 startwith func():

# %% [markdown]
# it return true if the word or char found at index 0 otherwi false

# %%
print(info)
print(info.startswith('muhammad'))#logically corecrt but programmaticaly python is case sensitive
print(info.startswith('Muhammad'))
info.startswith('M')
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# False
# True
# True

# %% [markdown]
# ### 10 endwith():

# %% [markdown]
# it is the opposite of startwith() return true if end with the specific word otherwie false

# %%
print(info)
print(info.endswith('Dir'))
print(info.endswith('r'))
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# True
# True

# %% [markdown]
# ### 11 split() func:

# %% [markdown]
# split function separate the string by a white space and convert it into a list

# %% [markdown]
# while it can also remove a specific word from the list by pasing it as a parameter into split function

# %%
print(info)
print(info.split())
info.split('Muhammad')#Muhammad removed
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# ['Muhammad', 'Ilyas', 'from', 'Maidan', 'Lower', 'Dir']
# ['', ' Ilyas from Maidan Lower Dir']

# %%
s=info.split('Maidan')
print(s)
# Out:
# ['Muhammad Ilyas from ', ' Lower Dir']

# %% [markdown]
# ### 12 join() func:

# %% [markdown]
# join function work as a concatination mean joining two string

# %% [markdown]
#  simply combining two string

# %%
print(info)
print(info.join(" "))
# Out:
# Muhammad Ilyas from Maidan Lower Dir

# %%
print(info)
print(info.join("  "))
# Out:
# Muhammad Ilyas from Maidan Lower Dir
#  Muhammad Ilyas from Maidan Lower Dir

# %%
print(info)
print(info.join("    "))
# Out:
# Muhammad Ilyas from Maidan Lower Dir
#  Muhammad Ilyas from Maidan Lower Dir Muhammad Ilyas from Maidan Lower Dir Muhammad Ilyas from Maidan Lower Dir

# %% [markdown]
# ### 13 isalpha():

# %% [markdown]
# check if string contain only alphabet if, so return true other wise false

# %%
print(info)
print(info.isalpha())#is not only alphabet it also contain whitespace so it iss not only alphabet result false
text='hello'#no any other charactr than alphabet re
text.isalpha()
# Out:
# Muhammad Ilyas from Maidan Lower Dir
# False
# True

# %% [markdown]
# ### 14 isdigit():

# %% [markdown]
# only check that given string is only digit

# %%
a='034999'
print(a.isdigit())
a='034999aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'#now with alphabet
a.isdigit()
# Out:
# True
# False

# %% [markdown]
# #  ------------------------THANK YOU -------------------

# %% [markdown]
# ## *****************MUHAMMAD ILYAS (AI)*******************
