# %% [markdown]
# if - else condition

# %%
age=int(input("age"))
salry=30000
if salry>15000:
    print("you are wealthy!")
# Out:
# you are wealthy!

# %% [markdown]
# match

# %%
marks=int(input("Enter your mark: "))
print("hello{}{}".format(marks,marks))
if marks>=90:
    print("A-grade")
elif marks>=80:
    print("B-grade")
elif marks>=70:
    print("c-grade")
elif marks>=60:
    print("d-grade")
else:
    print("failed!")
# Out:
# hello1818
# failed!

# %%
vowel=['A','E','i','O','U','a','e','i','o','u']
char=input("Enter a chacrater:")
if char in vowel:
    print(f"{char} is vowel")
else:
    print(f"{char} is consonant")
# Out:
# a is vowel

# %%
char=input("Enter a chacrater:")
l=len(char)
if l==1:
    if char in 'aeiouAEIOU':
        print(f"{char} is vowel")
    else:
        print(f"{char} is consonant")
else:
    print("you enter more than one character or nothing")
# Out:
# 6 is consonant

# %%
num=int(input("enter  a number :"))
if num%2==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
# 600 is even

# %%
prime=int(input("enter a number:"))
if prime%2==0:
    print(f"{prime} is not prime")
else:
    if prime%1==0 and prime%prime==0:
        print(f"{prime} is prime")
# Out:
# 13 is prime

# %%
username=input("enter your user name:")
password=input("enter your password:")

cuser="muhammad ilyas"
cpass="ahmad345"
lp=len(password)
if username==cuser and password==cpass:
    print("*************")
    print("Login Successfully!")
else:
    print("User name or password is incorrect!")
# Out:
# *************
# Login Successfully!

# %% [markdown]
# electricty bill calculation

# %%
unit=int(input("enter consumed unit:"))

if unit<=100:
    totalbill=unit*30
    print(f"your bill is :{totalbill} ")
elif 100 <unit<=200:
    totalbill=unit*50
    print(f"your bill :{totalbill}")
else:
    totalbill=unit*60
    print(f"your bill: {totalbill}")
# Out:
# your bill is :1350

# %% [markdown]
# ternary operator

# %% [markdown]
# One line code of condition

# %% [markdown]
# statement if condition else statement

# %%
tem=int(input("today temperature:"))
print("Weather is hot") if tem > 30 else print("Weather is pleasant!")
# Out:
# Weather is pleasant!

# %%
f=0
bool(f)
# Out:
# False

# %%
f=1
bool(f)
# Out:
# True

# %%
f=[1]
bool(f)
# Out:
# True

# %%
f=[]
bool(f)
# Out:
# False

# %% [markdown]
# #for loop

# %% [markdown]
# while

# %% [markdown]
# while condition:
#     statement
#     statement
