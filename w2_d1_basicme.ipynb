# %% [markdown]
# #list

# %% [markdown]
# data structure

# %% [markdown]
# sequence of value: in list ,tuple,dictionary ,set

# %% [markdown]
# naming list is same as variable name

# %% [markdown]
# student_mark=[1,3,5,7,9]

# %% [markdown]
# what is list?

# %% [markdown]
# ordered,mutable and can store multiple data types

# %%
student=["ahmad","muhammad","ilyas"]
print(student[1])
# Out:
# muhammad

# %%
empty=[]
print(empty[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 empty=[]
# ----> 2 print(empty[0])
#
# IndexError: list index out of range

# %%
age=int(20)
age
# Out:
# 20

# %%
student1=[30,"kahn",399,True]
student1
# Out:
# [30, 'kahn', 399, True]

# %% [markdown]
# #Array is a homogenous data structure :store data in a same memory location
# #linked list:do not store data in a same memory loacation
# #pointer and value array find address and value of the next element=>array are speed fast  and accurate data structure and memory effecient # one array=4 byte while list=8 byte

# %%
array=[3,5,6]

# %%
fruit=["apple","banana","mango"]
print(id(fruit))
# Out:
# 1405870172160

# %%
fruit.append("grape")
fruit
# Out:
# ['apple', 'banana', 'mango', 'grape', 'grape', 'grape']

# %%
ne_fruit=["melon","strawberry"]
fruit1=['apple', 'banana', 'mango', 'grape', 'grape', 'grape']

# %%
fruit1.append(ne_fruit)
print(fruit1)
# Out:
# ['apple', 'banana', 'mango', 'grape', 'grape', 'grape', ['melon', 'strawberry']]

# %% [markdown]
# #extend function

# %% [markdown]
# #remove function

# %% [markdown]
# #pop method

# %%
print(fruit1)
# Out:
# ['apple', 'banana', 'mango', 'grape', 'grape', 'grape', ['melon', 'strawberry']]

# %%
fruit1.pop()
# Out:
# ['melon', 'strawberry']

# %%
fruit1
# Out:
# ['apple', 'banana', 'mango', 'grape', 'grape', 'grape']

# %%
fruit1.remove("banana")

# %%
fruit1
# Out:
# ['apple', 'mango', 'grape', 'grape', 'grape']

# %%
fruit1.insert(3,"banana")

# %%
fruit1
# Out:
# ['apple', 'mango', 'grape', 'banana', 'grape', 'grape']

# %%
fruit[0][3]
# Out:
# 'l'

# %% [markdown]
# #list within a list

# %%
fruit1.append(['banana', 'grape'])

# %%
fruit1
# Out:
# ['apple', 'mango', 'grape', 'banana', 'grape', 'grape', ['banana', 'grape']]

# %%
fruit1[-1][1][3]#acces the value of grape 'p'
# Out:
# 'p'

# %%
fruit1[0][::-1]
# Out:
# 'elppa'

# %%
fr=['apple', 'mango', 'banana','grape']
id(fr)
# Out:
# 1405871670848

# %% [markdown]
# string: changing in string change the memory location of the data

# %% [markdown]
# list: changing ,mutability in list property allow the list to have same memory location

# %% [markdown]
# #insert

# %% [markdown]
# #delete

# %%
del fruit
print(fruit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 del fruit
#       2 print(fruit)
#
# NameError: name 'fruit' is not defined

# %% [markdown]
# #clear

# %% [markdown]
# #count

# %% [markdown]
# #index

# %%
fruit=['apple', 'mango', 'banana','grape']
fruit.insert()

# %% [markdown]
# #clear

# %%
fruit1
# Out:
# ['apple', 'mango', 'grape', 'banana', 'grape', 'grape', ['banana', 'grape']]

# %%
fruit1.insert(4,"peach")

# %%
fruit1
# Out:
# ['apple',
#  'mango',
#  'grape',
#  'banana',
#  'peach',
#  'grape',
#  'grape',
#  ['banana', 'grape']]

# %%
fruit1.reverse()

# %%
fruit1
# Out:
# [['banana', 'grape'],
#  'grape',
#  'grape',
#  'peach',
#  'banana',
#  'grape',
#  'mango',
#  'apple']

# %% [markdown]
# Parmanent function and temporary function copy vs view

# %%
fruit2=fruit1
print(id(fruit2))
id(fruit1)
# Out:
# 1405871253504
# 1405871253504

# %%
fruit2=fruit1.copy()

# %%
id(fruit2)
# Out:
# 1405871471488

# %%
fruit3=fruit1[:]
id(fruit3)
# Out:
# 1405871913472

# %%
number=[10,20,30,40,50]
print(f"first number : {number[0]}\nlast number : {number[-1]}\nMiddle number :{number[2]}\ntotal element:{len(number)}\
      \ntotal sum :{sum(number)}")
# Out:
# first number : 10
# last number : 50
# Middle number :30
# total element:5
# total sum :150

# %%
number=[10,20,30,40,50]
print(f"{number[0]} \n{number[-1]} \n{number[2]} \n{len(number)} \n{sum(number)}")
# Out:
# 10
# 50
# 30
# 5
# 150

# %% [markdown]
# #dictionary
# that type of data structure in which value/data are stored in the form of key and value

# %% [markdown]
# key can be any data type

# %%
student={"Name":"ahmad","Age":30}

# %%
student
# Out:
# {'Name': 'ahmad', 'Age': 30}

# %% [markdown]
# to find index :

# %% [markdown]
# using key :so we can access the value

# %%
student[age]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 student[age]
#
# NameError: name 'age' is not defined

# %%
print(student["Age"])
# Out:
# 30

# %%
print(student.keys())
# Out:
# dict_keys(['Name', 'Age'])

# %%
print(student.values())
# Out:
# dict_values(['ahmad', 30])

# %% [markdown]
# student["pass"]="yes"

# %% [markdown]
# How  to add new key value in dictionary

# %%
student["pass"]="yes"

# %%
print(student)
# Out:
# {'Name': 'ahmad', 'Age': 30, 'pass': 'yes'}
