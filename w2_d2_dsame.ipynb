# %% [markdown]
# #dictionary

# %%
student={
    "name":"muhammad ibad",
    "age":40,
    "mark":400
}
print(student)
# Out:
# {'name': 'muhammad ibad', 'age': 40, 'mark': 400}

# %% [markdown]
# accessing data

# %%
print("name:",student['name'])
print("age:",student['age'])
print("mark:",student['mark'])
print("name:",student['name'])
# Out:
# name: muhammad ibad
# age: 40
# mark: 400
# name: muhammad ibad

# %%
student.get("age")
# Out:
# 40

# %%
student.get("mark")
# Out:
# 400

# %%
student.get("name")
# Out:
# 'muhammad ibad'

# %% [markdown]
# #changes

# %%
student["mark"]=[99,78]

# %%
student
# Out:
# {'name': 'muhammad ibad', 'age': 40, 'mark': [99, 78]}

# %%
student['mark'].append(69)

# %%
student
# Out:
# {'name': 'muhammad ibad', 'age': 40, 'mark': [99, 78, 69]}

# %%
student.update({"name":"muhammad ilyas","contact":"988888"})

# %%
student
# Out:
# {'name': 'muhammad ilyas',
#  'age': 40,
#  'mark': [99, 78, 69],
#  'contact': '988888'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'mark', 'contact'])

# %%
student.pop("age")
# Out:
# 40

# %%
student
# Out:
# {'name': 'muhammad ilyas', 'mark': [99, 78, 69], 'contact': '988888'}

# %%
student.update({"age":40})

# %%
student
# Out:
# {'name': 'muhammad ilyas',
#  'mark': [99, 78, 69],
#  'contact': '988888',
#  'age': 40}

# %%
student.keys()
# Out:
# dict_keys(['name', 'mark', 'contact', 'age'])

# %%
student.items()
# Out:
# dict_items([('name', 'muhammad ilyas'), ('mark', [99, 78, 69]), ('contact', '988888'), ('age', 40)])

# %%
student.items()
# Out:
# dict_items([])

# %%
student.values()
# Out:
# dict_values([])

# %%
student={
    "student1":{
    "name":"muhammad ibad",
    "age":40,
    "mark":400
    }
    "student2":{
    "name":"muhammad ibad",
    "age":40,
    "mark":400
}
}
print(student)

# %%
student={
    "name":"muhammad ibad",
    "age":40,
    "mark":400
}
print(student)
student.popitem()
student
student.pop("name")
# Out:
# {'name': 'muhammad ibad', 'age': 40, 'mark': 400}
# 'muhammad ibad'

# %%
student
# Out:
# {'age': 40}

# %%
#tuple
#by constructor
t=tuple()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t2=(43,45,46)
t2[1]
# Out:
# 45

# %% [markdown]
# #tuple are immutable data structure

# %%
t[1]=54
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t[1]=54
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t2.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
#tuple packing and unpacking

# %%
a,b,c=t2

# %%
t2
# Out:
# (43, 45, 46)

# %%
print(a)
# Out:
# 43

# %%
#unpacking

# %%
t3=13,14,15,16

# %%
t3
# Out:
# (13, 14, 15, 16)

# %%
#list ki andar tuple

# %% [markdown]
# convert dictionary into list then save as a tuple then access by indexing

# %%
#set

# %% [markdown]
# set are unique mean having no duplicate value

# %% [markdown]
# set are immutable

# %%
s1={1111,3,4,5,6}

# %%
s1
# Out:
# {3, 4, 5, 6, 1111}

# %%
print(type(set))
# Out:
# <class 'type'>

# %%
s3={1,3,3,3,4,5,6,3}

# %%
s3
# Out:
# {1, 3, 4, 5, 6}

# %%
s3.add(9)

# %%
s3
# Out:
# {1, 3, 4, 5, 6, 9}

# %% [markdown]
# set are mutable but there element must be unmutable

# %% [markdown]
# #union

# %%
s5={1,3,5,6,4,7,8,6}
s6={1,4,5,4,55,6,6,9,90}
print(s5.union(s6))
# Out:
# {1, 3, 4, 5, 6, 7, 8, 9, 55, 90}

# %% [markdown]
# intersection

# %%
print(s6.intersection(s5))
# Out:
# {1, 4, 5, 6}

# %%
s5.symmetric_difference(s6)
# Out:
# {3, 7, 8, 9, 55, 90}

# %%
s6.symmetric_difference(s5)
# Out:
# {3, 7, 8, 9, 55, 90}

# %% [markdown]
# concatination possible

# %%
l={1,4,5,6,7,8,9}

# %%
l.remove(4)

# %%
l
# Out:
# {1, 5, 6, 7, 8, 9}

# %%
l.pop()
# Out:
# 1

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
del
# Out:
#   Cell In[51], line 1
#     del
#        ^
# SyntaxError: invalid syntax

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
s5
# Out:
# {1, 3, 4, 5, 6, 7, 8}

# %%
s5=frozenset()

# %%
s5
# Out:
# frozenset()

# %%
s5.add(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 s5.add(4)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s6.add(3)

# %%
s6
# Out:
# {1, 3, 4, 5, 6, 9, 55, 90}

# %% [markdown]
# function use curly braces

# %%
l=[(x1),()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 l=[(x1),()]
#
# NameError: name 'x1' is not defined

# %%
point=[(3,4),(5,6),(1,3),(8,1),(3,1)]
z1=point[0][0]
y1=point[0][1]
d1=(z1**2+y1**2)**(1/2)
print(d1)
z2=point[1][0]
y2=point[1][1]
d2=(z2**2+y2**2)**(1/2)
print(d2)
z3=point[2][0]
y3=point[2][1]
d3=(z3**2+y3**2)**(1/2)
print(d3)
z4=point[3][0]
y4=point[3][1]
d4=(z4**2+y4**2)**(1/2)
print(d4)
z5=point[4][0]
y5=point[4][1]
d5=(z5**2+y5**2)**(1/2)
print(f"{d5}")
# Out:
# 5.0
# 7.810249675906654
# 3.1622776601683795
# 8.06225774829855
# 3.1622776601683795

# %% [markdown]
# 12.5
# 30.5
# 3.1622776601683795
# 32.5
# 5.0

# %% [markdown]
# Student record

# %%
lit=[("ahmad",15,'a',3.5),("muhammad",16,'a',3.7),('hamid',17,'b',4),('mahmood',17,'a',3.9)]

# %%
gpas=lit[0][3],lit[1][3],lit[2][3],lit[3][3]

# %%
print(gpas)
# Out:
# (3.5, 3.7, 4, 3.9)

# %%
max_gpa=max(gpas)

# %%
print(max_gpa)
# Out:
# 4

# %%
ind_max=gpas.index(max_gpa)

# %%
print(lit[ind_max])
# Out:
# ('hamid', 17, 'b', 4)

# %%
age=lit[0][1],lit[1][1],lit[2][1],lit[3][1]
print(age)
# Out:
# (15, 16, 17, 17)

# %%
av_age=sum(age)/len(age)
print(av_age)
# Out:
# 16.25

# %%
grade=lit[0][2],lit[1][2],lit[2][2],lit[3][2]
print(grade)
# Out:
# ('a', 'a', 'b', 'a')
# 0

# %%
agrade=grade.count("a")

# %%
print(agrade)
# Out:
# 3

# %%
ne_gpa=[gpas]
ne_gpa
# Out:
# [(3.5, 3.7, 4, 3.9)]

# %%
a,b,c,d=gpas

# %%
a
# Out:
# 3.5

# %%
gpalit=[a,b,c,d]
gpalit.sort()
print(gpalit)
print(gpalit)
# Out:
# [3.5, 3.7, 3.9, 4]
# [3.5, 3.7, 3.9, 4]
