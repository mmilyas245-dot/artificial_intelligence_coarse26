# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr1=np.random.randint(128,256,128).reshape(-1,8)

# %%
arr1
# Out:
# array([[183, 214, 157, 175, 164, 243, 137, 195],
#        [159, 154, 250, 171, 214, 243, 244, 254],
#        [232, 192, 171, 193, 153, 179, 206, 220],
#        [130, 250, 170, 241, 136, 183, 214, 186],
#        [157, 170, 246, 169, 133, 169, 137, 251],
#        [206, 203, 249, 154, 228, 153, 169, 247],
#        [217, 225, 224, 253, 208, 179, 232, 134],
#        [171, 234, 149, 228, 148, 190, 246, 165],
#        [175, 145, 137, 234, 222, 180, 193, 169],
#        [157, 200, 135, 136, 169, 225, 248, 160],
#        [249, 172, 234, 192, 213, 145, 226, 235],
#        [229, 136, 254, 188, 209, 220, 169, 232],
#        [234, 174, 182, 179, 245, 193, 188, 249],
#        [228, 183, 237, 158, 184, 196, 170, 178],
#        [169, 172, 186, 136, 175, 171, 214, 128],
#        [236, 130, 184, 219, 179, 240, 212, 228]], dtype=int32)

# %%
plt.imshow(arr1)
plt.axis("OFF")
plt.show()

# %%
red= np.array([[[255,0,0]]])
red.shape
# Out:
# (1, 1, 3)

# %%
plt.imshow(red)

# %%
green = np.array([[[0,255,0]]])

# %%
plt.imshow(green)

# %%
blue=np.array([[[0,0,255]]])

# %%
plt.imshow(blue)

# %%
data=[red,green,blue]

# %%
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.pairplot(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\axisgrid.py:2103, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2100     warnings.warn(msg, UserWarning)
#    2102 if not isinstance(data, pd.DataFrame):
# -> 2103     raise TypeError(
#    2104         f"'data' must be pandas DataFrame object, not: {type(data)}")
#    2106 plot_kws = {} if plot_kws is None else plot_kws.copy()
#    2107 diag_kws = {} if diag_kws is None else diag_kws.copy()
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'list'>

# %%
plt.imshow(np.array([[[255,0,0]]]))
