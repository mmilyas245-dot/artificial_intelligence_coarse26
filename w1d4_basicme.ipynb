# %% [markdown]
# Data Structure:

# %%
text ="   this   is my first program  "
text.strip()

# %%
text ="   this   is my first program  "
print(text.strip())
print(text)
# Out:
# this   is my first program
#    this   is my first program

# %%
list1=["apple","banana","orange"]
print(list1)
# Out:
# ['apple', 'banana', 'orange']

# %%
print(list1[0])
# Out:
# apple

# %%
print(",".join(list1))
# Out:
# apple,banana,orange

# %%
print("+".join(list1))
# Out:
# apple+banana+orange

# %%
text3 = """I joined with a personal passion for crypto and finance and I’m leaving with a much deeper understanding of the business, the technology, the regulatory landscape, and what it takes to build in one of the fastest moving industries in the world"""

# %%
print(text3)
# Out:
# I joined with a personal passion for crypto and finance and I’m leaving with a much deeper understanding of the business, the technology, the regulatory landscape, and what it takes to build in one of the fastest moving industries in the world

# %%
print(text3.count("the"))
# Out:
# 5

# %% [markdown]
# ##find function
# #index function

# %% [markdown]
# #slicing

# %% [markdown]
# list:
# list is ordered collection of data type ,mutable

# %% [markdown]
# Indexing / location in python alway start from 0

# %% [markdown]
# len() function use to identify the length of a sequence.

# %%
fruit=["apple","banana","orange"]
print(fruit)
#fruit[0]
len([fruit])
# Out:
# ['apple', 'banana', 'orange']
# 1

# %% [markdown]
# slicing ka tareqa:
# fruit[start:stop:steps] ==>> step mean jump , starting index will be included , stoping index is not included

# %%
text= "the fourth day of ai journey"

# %%
text[0:10:1]
# Out:
# 'the fourth'

# %%
text [0:30:3]
# Out:
# 't uhaoajry'

# %%
text [::]
# Out:
# 'the fourth day of ai journey'

# %%
text[::5]
# Out:
# 'to o n'

# %%
fruit=["apple","banana","orange"]
list1=fruit.reverse()
#print(list1)
for i in fruit:
    print(i)
# Out:
# orange
# banana
# apple

# %% [markdown]
# Calculator:

# %%
a=5
b=50
add=a+b
minus=a-b
multiply=a*b
divide=a/b
print("Addition is: ",add)
print("Subtraction is: ",minus)
print("Multiplication is: ",multiply)
print("Division is: ",divide)
# Out:
# Addition is:  55
# Subtraction is:  -45
# Multiplication is:  250
# Division is:  0.1

# %% [markdown]
# if you want only digit after decimal point:=> variable_name:.3f =>mean only 3 floating point

# %%
a =10
b=20
if a>b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# #take input from the user

# %%
input1 = input("Enter your name: ")
print("Hello, " + input1 + "! Welcome to the program.")
# Out:
# Hello, ahmad! Welcome to the program.

# %% [markdown]
# input function in python will alway take as a string by default:
# let check with a number addition.

# %%
num1=input("enter a number: ")
num2=input("enter a number: ")
print(int(num1)+int(num2))
print(num1+num2)
# Out:
# 10
# 55

# %% [markdown]
# Body Mass Index:

# %%
kilograms=float(input("enter your weight in kilograms: "))
meters=float(input("enter your height in meters: "))
bmi=kilograms/(meters**2)
print(f"your Body mass index is: {bmi:.2f}")
if bmi <18.5:
    print("you are under wieght")
elif bmi>18.5 and bmi<24.9:
    print("you are normal")
else:
    print("you are overwieght")
# Out:
# your Body mass index is: 24.69
# you are normal

# %% [markdown]
# comparison operator(6): ==,!=,>,<=,>=

# %% [markdown]
# logical operator: yes,no,and,or,true,false

# %%
student_mark1=80
student_mark2=99
print(student_mark1==student_mark2)
print(student_mark1<student_mark2)
print(student_mark1>=student_mark1)
# Out:
# False
# True
# True

# %% [markdown]
# by operator we can take multiple decision.

# %%
name1='ali'
name2='ahmad'
print(name1==name2)
name1=name2#value of 2nd variable replaced 1st
print(name1)
# Out:
# False
# ahmad

# %% [markdown]
# #PEMDAs rule:

# %% [markdown]
# arithmetic operator precedence in python

# %% [markdown]
# Unary operator:

# %% [markdown]
# single operator used with variable

# %% [markdown]
# Membership operator:
# is a member of

# %% [markdown]
# 1)in
# 2)not in

# %%
students=["talha","abbas,jawad","ilyas","ibad"]
"ilyas" in students
# Out:
# True

# %% [markdown]
# ##assignment operator

# %%
age=10
print(age)
age+1
print(age)
print(age+1)
age+=1
print(age)
# Out:
# 10
# 10
# 11
# 11

# %% [markdown]
# #identity operator

# %%
#is=>>>. identify value based on their id() 
# when the value is small so same location is assigned
a=5
b=5
a is b
# Out:
# True

# %%
print(id(a))
id(b)
# Out:
# 140712605684776
# 140712605684776

# %%
a is b
# Out:
# True

# %% [markdown]
# is not

# %%
#is not
age=40
age1=50
age is not age1
# Out:
# True

# %% [markdown]
# logical operator

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
user = input("enter user_name:")

# %% [markdown]
# #bitwise operator

# %%
#&
True & True
# Out:
# True

# %% [markdown]
# #pipepline symbol

# %%
True | False
# Out:
# True

# %%
False | False
# Out:
# False

# %% [markdown]
# XOR => exclusive or

# %%
True ^ True
# Out:
# False

# %%
False ^ False
# Out:
# False

# %%
6 & 5
# Out:
# 4
