# %% [markdown]
# # Saeborn library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r"C:\artificial_intelligence_coarse\sir_git_ai\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\week-04-libraries-descriptive-statistics\datasets\students.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   184 non-null    str
#  1   gender       184 non-null    str
#  2   city         184 non-null    str
#  3   program      184 non-null    str
#  4   semester     184 non-null    int64
#  5   study_hours  179 non-null    float64
#  6   attendance   168 non-null    float64
#  7   prev_gpa     174 non-null    float64
#  8   final_marks  184 non-null    float64
#  9   scholarship  184 non-null    int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 14.5 KB

# %%
for column in ["study_hours","attendance","prev_gpa"]:
    df[column]=df[column].fillna(df[column].mean())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   184 non-null    str
#  1   gender       184 non-null    str
#  2   city         184 non-null    str
#  3   program      184 non-null    str
#  4   semester     184 non-null    int64
#  5   study_hours  184 non-null    float64
#  6   attendance   184 non-null    float64
#  7   prev_gpa     184 non-null    float64
#  8   final_marks  184 non-null    float64
#  9   scholarship  184 non-null    int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 14.5 KB

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'male', 'female']
# Length: 4, dtype: str

# %%
df['gender']=df['gender'].apply(lambda s:s.lower())

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str

# %%
df.city.unique()
# Out:
# <StringArray>
# [   'Quetta',   'Karachi',    'Lahore',  'PESHAWAR',  'Peshawar',   'KARACHI',
#     'Multan', 'Islamabad']
# Length: 8, dtype: str

# %%
df.city=df.city.str.title()

# %%
df.city.unique()
# Out:
# <StringArray>
# ['Quetta', 'Karachi', 'Lahore', 'Peshawar', 'Multan', 'Islamabad']
# Length: 6, dtype: str

# %%
df[['attendance','study_hours']].corr()
# Out:
#              attendance  study_hours
# attendance     1.000000    -0.031473
# study_hours   -0.031473     1.000000

# %%
sns.regplot(data=df,x='study_hours',y='attendance')
# Out:
# <Axes: xlabel='study_hours', ylabel='attendance'>

# %%
sns.histplot(data=df,x='study_hours')
plt.title('study hour plot')
plt.show()

# %%
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(data=df,x='final_marks',color='red')
plt.axvline(np.percentile(df['final_marks'],5))

# %%
sns.scatterplot(data=df,x='study_hours',y='final_marks',marker='*',c='r')
# Out:
# <Axes: xlabel='study_hours', ylabel='final_marks'>

# %%
sns.regplot(data=df, x="study_hours", y='final_marks', label='marks', scatter_kws={"alpha":0.8},line_kws={"color":"red",'label':"Reg line"})
# Out:
# <Axes: xlabel='study_hours', ylabel='final_marks'>

# %%
sns.pairplot(data=df[['study_hours','attendance','prev_gpa',]])

# %%
x=df[['study_hours','attendance','prev_gpa']]#independant variable x

# %%
x.head()
# Out:
#    study_hours  attendance  prev_gpa
# 0          8.1        87.5  1.910000
# 1          5.2        77.4  2.839655
# 2          4.0        96.9  2.839655
# 3          2.5       100.0  2.840000
# 4          7.7        87.8  2.839655

# %%
y=df['final_marks']

# %%
df.isnull().sum()
# Out:
# student_id     0
# gender         0
# city           0
# program        0
# semester       0
# study_hours    0
# attendance     0
# prev_gpa       0
# final_marks    0
# scholarship    0
# dtype: int64

# %%
arr=[[1,2,3],
     [4,5,6],
     [7,8,9]]

# %%
sns.heatmap(arr,vmin=1,vmax=10)
# Out:
# <Axes: >

# %%
cor=df[['attendance','study_hours','prev_gpa','final_marks']].corr()

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
fig,ax=plt.subplots(1,2,figsize=(8,4))
ax[0].scatter(df['study_hours'],df['final_marks'])
ax[1].scatter(df['attendance'],df['final_marks'])

# %%
df1=pd.read_csv(r'C:\artificial_intelligence_coarse\sir_git_ai\Artificial-Inteligence-Machine-Learning-and-Deep-Learning-NAVTTC-Course-2026\week-05-visualization-first-models-and-ML\datasets\automobileEDA.csv')
