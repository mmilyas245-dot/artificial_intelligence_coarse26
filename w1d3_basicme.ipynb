# %%
print("hello! my name is muhammad")
# Out:
# hello! my name is muhammad

# %%
name="ilyas"

# %%
age=20

# %%
name="ilyas"
age=20
print("your name is", name, "and your age is", age)
# Out:
# your name is ilyas and your age is 20

# %%
print(name, age,sep="")
# Out:
# ilyas20

# %%
print(name,"\n",age)
# Out:
# ilyas
#  20

# %%
print("i am {0} and i am {1} years old".format(name,age))
# Out:
# i am ilyas and i am 20 years old

# %%
#let's comment this line
print("ahmad \t ali")
# Out:
# ahmad 	 ali

# %%
#how to code qoutation marks
print("\"ahmad\" ")
print('"Ahmad"')
# Out:
# "ahmad"
# "Ahmad"

# %%
#raw string mean actual string without any escape sequence
path=r"C:\artificial_intelligence_coarse\w1d3_basic.ipynb"
print(path)
# Out:
# C:\artificial_intelligence_coarse\w1d3_basic.ipynb

# %%
#end parameter ,do not go to new line after print statement
print("hello","world","this is a test", end=" ")
# Out:
# hello world this is a test

# %%
print("my brother name is ahmad-ali", end=" ")
print("welcome to programming world", end=" ")
print("this is a test for end parameter")
# Out:
# my brother name is ahmad-ali welcome to programming world this is a test for end parameter

# %%
#\r reverse the first name from the second name
print("ahmad\rali")
# Out:
# aliad

# %%
#\b backspace or cut one word from the first name
print("ahma\bali")
# Out:
# ahmali

# %% [markdown]
# String:

# %%
first_name="ahmad"
last_name="ali"

# %% [markdown]
# 1)concatenation

# %%
fullname=first_name+" "+last_name
print(fullname)
# Out:
# ahmad ali

# %% [markdown]
# 2)universal function =>uppercase

# %%
first_name="ahmad"
last_name="ali"
fullname=first_name+" "+last_name
print(fullname)
upper_name=fullname.upper()
print(upper_name)
# Out:
# ahmad ali
# AHMAD ALI

# %%
name="ahmad"
print(name.capitalize())
# Out:
# Ahmad

# %%
text=r"I’m a Computer Science student and entrepreneur driven by a pretty simple goal: building technology that actually solves real world problems. Whether it's developing web and mobile apps, building AI agents, or automating clunky workflows, I love taking a raw idea and turning it into a functional, practical product.\nMy journey so far has been a mix of intense learning and execution. I’ve founded a startup, won hackathons, and participated in multiple tech bootcamps experiences that taught me how to move fast and think creatively. I’ve also had the chance to step into both sides of the classroom, learning from industry experts and instructing others in technical training programs to help them bridge the digital skills gap."

# %%
print(text.count("i", 0, 100))
# Out:
# 5

# %%
import matplotlib.pyplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import matplotlib.pyplot
#
# ModuleNotFoundError: No module named 'matplotlib'
